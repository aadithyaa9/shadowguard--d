# %%
import pandas as pd

df = pd.read_csv("my_normal_traffic.csv")

df.shape
df.head()
# Out:
#    Destination Port  Total Fwd Packets  Total Backward Packets  \
# 0           44000.0                7.0                     5.0
# 1           37980.0                1.0                     1.0
# 2           37980.0                2.0                     2.0
# 3             443.0                1.0                     1.0
# 4             443.0               89.0                   118.0
#
#    Total Length of Fwd Packets  Total Length of Bwd Packets  \
# 0                        834.0                       3221.0
# 1                         94.0                         66.0
# 2                        188.0                        132.0
# 3                         66.0                         66.0
# 4                       7818.0                     174249.0
#
#    Min Packet Length  Max Packet Length  Packet Length Mean  \
# 0               66.0             1494.0          337.916667
# 1               66.0               94.0           80.000000
# ...

# %%
print(df.columns.tolist())
# Out:
# ['Destination Port', 'Total Fwd Packets', 'Total Backward Packets', 'Total Length of Fwd Packets', 'Total Length of Bwd Packets', 'Min Packet Length', 'Max Packet Length', 'Packet Length Mean', 'Packet Length Std', 'Flow Duration', 'Flow IAT Mean', 'Flow IAT Std', 'SYN Flag Count', 'ACK Flag Count', 'FIN Flag Count', 'RST Flag Count', 'PSH Flag Count']

# %%
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()

X_scaled = scaler.fit_transform(df)

# %%
import tensorflow as tf
from tensorflow.keras import layers, models

input_dim = X_scaled.shape[1]

autoencoder = models.Sequential([
    layers.Dense(8, activation='relu', input_shape=(input_dim,)),
    layers.Dense(4, activation='relu'),
    layers.Dense(8, activation='relu'),
    layers.Dense(input_dim, activation='linear')
])

autoencoder.compile(optimizer='adam', loss='mse')

autoencoder.summary()
# Out:
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/core/dense.py:106: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ dense (Dense)                   │ (None, 8)              │           144 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 4)              │            36 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_2 (Dense)                 │ (None, 8)              │            40 │
# ...

# %%
history = autoencoder.fit(
    X_scaled,
    X_scaled,
    epochs=20,
    batch_size=512,
    validation_split=0.1,
    shuffle=True
)
# Out:
# Epoch 1/20
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 2s 90ms/step - loss: 1.1811 - val_loss: 0.8723
# Epoch 2/20
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 1.1435 - val_loss: 0.8276
# Epoch 3/20
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 1.1123 - val_loss: 0.7898
# Epoch 4/20
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 1.0837 - val_loss: 0.7581
# Epoch 5/20
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 1.0606 - val_loss: 0.7334
# Epoch 6/20
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 1.0416 - val_loss: 0.7129
# Epoch 7/20
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 1.0238 - val_loss: 0.6964
# Epoch 8/20
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 1.0083 - val_loss: 0.6832
# Epoch 9/20
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 0.9936 - val_loss: 0.6729
# Epoch 10/20
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 0.9806 - val_loss: 0.6653
# Epoch 11/20
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 0.9671 - val_loss: 0.6594
# Epoch 12/20
# ...

# %%
import numpy as np

reconstructions = autoencoder.predict(X_scaled, batch_size=512)

train_loss = np.mean(np.square(X_scaled - reconstructions), axis=1)

threshold = 2.0989840833281423

print("New Threshold:", threshold)
# Out:
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step
# New Threshold: 2.0989840833281423

# %%
import joblib

# Save scaler
joblib.dump(scaler, "scaler_real.pkl")

# Save threshold
joblib.dump(threshold, "ae_threshold_real1.pkl")

# Save model (modern format)
autoencoder.save("autoencoder_real.keras")

# %%
import tensorflow as tf

# Load your trained model
model = tf.keras.models.load_model("autoencoder_real.keras", compile=False)

# Re-save in legacy HDF5 format (compatible)
model.save("autoencoder_real_fixed.h5")
# Out:
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.

# %%
from google.colab import files
files.download("autoencoder_real_fixed.h5")

# %%
import pandas as pd

df = pd.read_csv("my_normal_traffic.csv")

sample = df.head(5)  # take 5 rows

sample.to_csv("sample.csv", index=False)

# %%
# Out:
# 2.0989840833281423
